# %% [markdown]
# # Initialization

# %%
using PyPlot
import Plots
Plots.pyplot()
using Revise

# %%
using Comparison
using Multi

# %%
A, p, M = gridProblem();

# %%
greedy = timeTilPickup(greedyPolicy(A,p), A, p, 100);
rnd = timeTilPickup(randPolicy(A), A, p, 100);

# %%
plt[:hist](greedy, normed=true, alpha=0.5);
plt[:hist](rnd, normed=true, alpha=0.5);
legend(["greedy", "random"])
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x7f15eb9d2198>

# %%
model, logs = Multi.fleetIterWalk(A, p, 3);

# %%
logs

# %%
predict(model, logs)

# %%
# We do an image plot of x axis as time, y axis as idle time`
